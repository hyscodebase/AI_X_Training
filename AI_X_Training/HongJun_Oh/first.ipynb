# %%
def funny_template(name="친구", occasion="생일"):
	template = f"""
	======= 웃긴 템플릿 =======
	{name}님, 오늘은 {occasion}이니까
	축하 대신 깜짝 놀람을 준비하세요!
	🎉 당신의 하루는 벌써 200% 재미있습니다.
	(사실은 300%까지 올릴 수 있어요)
	===========================
	"""
	print(template)

# 사용 예
funny_template("철수", "생일")
# Out:
# 	======= 웃긴 템플릿 =======
# 	철수님, 오늘은 생일이니까
# 	축하 대신 깜짝 놀람을 준비하세요!
# 	🎉 당신의 하루는 벌써 200% 재미있습니다.
# 	(사실은 300%까지 올릴 수 있어요)
# ...
